# %%
import pandas as pd
import numpy as np

# %%
netflix = pd.read_csv("netflix_titles.csv")

# %%
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # most common rating

# %%
netflix["rating"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The most common rating is TV-MA

# %% [markdown]
# # percents of TV shows and Movies

# %%
netflix["type"].value_counts(normalize=True).plot.pie()
# Out:
# <AxesSubplot:ylabel='type'>

# %%
5377/7787
# Out:
# 0.6905098240657506

# %%
2410/7787
# Out:
# 0.3094901759342494

# %% [markdown]
# about 60% of data are movies and about 30% are Tv shows

# %% [markdown]
# # year that releaced most movies

# %%
movie_bool = netflix["type"] == "Movie"
movies = netflix[movie_bool].copy()
movies
# Out:
#      show_id   type                                    title  \
# 1         s2  Movie                                     7:19
# 2         s3  Movie                                    23:59
# 3         s4  Movie                                        9
# 4         s5  Movie                                       21
# 6         s7  Movie                                      122
# ...      ...    ...                                      ...
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7783   s7784  Movie                                   Zubaan
# 7784   s7785  Movie                        Zulu Man in Japan
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# ...

# %%
movies["release_year"].value_counts()
# Out:
# 2017    744
# 2018    734
# 2016    642
# 2019    582
# 2020    411
#        ...
# 1947      1
# 1959      1
# 1964      1
# 1963      1
# 1946      1
# Name: release_year, Length: 72, dtype: int64

# %% [markdown]
# the year 2017 releced the most movies

# %% [markdown]
# # Year that releced the most tv shows

# %%
tv = netflix[netflix["type"]=="TV Show"].copy()
tv
# Out:
#      show_id     type                  title              director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7767   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7775   s7776  TV Show             Zoids Wild                   NaN
# 7777   s7778  TV Show            Zombie Dumb                   NaN
# 7779   s7780  TV Show              Zona Rosa                   NaN
# 7785   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
tv["release_year"].value_counts()
# Out:
# 2020    457
# 2019    414
# 2018    387
# 2017    268
# 2016    240
# 2015    159
# 2014     90
# 2013     65
# 2012     61
# 2011     39
# 2010     37
# 2009     34
# 2008     23
# 2021     19
# 2006     13
# 2007     13
# 2005     12
# 2004      9
# 2003      9
# 1999      7
# 2002      6
# 2000      4
# 1998      4
# 1993      4
# 1997      4
# 2001      4
# 1990      3
# 1996      3
# 1992      2
# 1988      2
# 1995      2
# 1986      2
# 1994      1
# 1974      1
# 1972      1
# 1968      1
# 1925      1
# 1963      1
# 1967      1
# 1977      1
# 1979      1
# 1981      1
# 1985      1
# 1989      1
# 1991      1
# 1946      1
# Name: release_year, dtype: int64

# %% [markdown]
# 2020

# %% [markdown]
# # most movies directed

# %%
movies["director"].value_counts()
# Out:
# Raúl Campos, Jan Suter      18
# Marcus Raboy                15
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Jay Chapman                 12
#                             ..
# Fred M. Wilcox               1
# Lenin Bharathi               1
# Santram Varma                1
# Jonathan A. Rosenbaum        1
# Laura Alvea, José Ortuño     1
# Name: director, Length: 3909, dtype: int64

# %% [markdown]
# Raúl Campos, Jan Suter directed the most movies

# %% [markdown]
# # Directed most tv shows

# %%
tv["director"].value_counts()
# Out:
# Alastair Fothergill                      3
# Iginio Straffi                           2
# Rob Seidenglanz                          2
# Stan Lathan                              2
# Ken Burns                                2
#                                         ..
# Greg Tiernan                             1
# Julia Willoughby Nason, Jenner Furst     1
# Laurent Bouzereau                        1
# Jung-ah Im                               1
# Andrucha Waddington, Pedro Waddington    1
# Name: director, Length: 177, dtype: int64

# %% [markdown]
# # movies product countries

# %%
movies["country"].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # longest movies

# %%
duration_int = movies["duration"].str.replace("min", "").str.strip().astype(int)
movies["duration_int"] = duration_int
movies
# Out:
#      show_id   type                                    title  \
# 1         s2  Movie                                     7:19
# 2         s3  Movie                                    23:59
# 3         s4  Movie                                        9
# 4         s5  Movie                                       21
# 6         s7  Movie                                      122
# ...      ...    ...                                      ...
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7783   s7784  Movie                                   Zubaan
# 7784   s7785  Movie                        Zulu Man in Japan
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# ...

# %%
movies.sort_values("duration_int", ascending=False).head(10)
# Out:
#      show_id   type                       title                director  \
# 957     s958  Movie  Black Mirror: Bandersnatch                     NaN
# 6850   s6851  Movie      The School of Mischief  Houssam El-Din Mustafa
# 4490   s4491  Movie              No Longer kids         Samir Al Asfory
# 3694   s3695  Movie          Lock Your Girls In       Fouad El-Mohandes
# 5108   s5109  Movie             Raya and Sakina           Hussein Kamal
# 5376   s5377  Movie                      Sangam              Raj Kapoor
# 3521   s3522  Movie                      Lagaan      Ashutosh Gowariker
# 3195   s3196  Movie                Jodhaa Akbar      Ashutosh Gowariker
# 6507   s6508  Movie                The Irishman         Martin Scorsese
# 3282   s3283  Movie    Kabhi Khushi Kabhie Gham             Karan Johar
#
#                                                    cast        country  \
# 957   Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
# ...

# %% [markdown]
# # Average length of seasons

# %%
tv_striped = tv["duration"].str.replace("Season", "")

# %%
tv["tv_striped"] = tv_striped
tv
# Out:
#      show_id     type                  title              director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7767   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7775   s7776  TV Show             Zoids Wild                   NaN
# 7777   s7778  TV Show            Zombie Dumb                   NaN
# 7779   s7780  TV Show              Zona Rosa                   NaN
# 7785   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
tv_striped_s = tv["tv_striped"].str.replace("s", "")

# %%
tv["tv_striped_s"] = tv_striped_s

# %%
tv
# Out:
#      show_id     type                  title              director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7767   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7775   s7776  TV Show             Zoids Wild                   NaN
# 7777   s7778  TV Show            Zombie Dumb                   NaN
# 7779   s7780  TV Show              Zona Rosa                   NaN
# 7785   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
tv["tv_striped_s"].astype(int).mean()
# Out:
# 1.7759336099585061

# %% [markdown]
# # longest running

# %%
tv["tv_striped_s"].astype(int).max()
# Out:
# 16

# %%
director_tv = tv[tv["tv_striped_s"]==16]
director_tv
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, tv_striped, tv_striped_s]
# Index: []

# %% [markdown]
# there are is no directors for this tv show

# %% [markdown]
# # CHALLENGE

# %%
genres = movies["listed_in"].str.split(",").explode().str.strip().value_counts()
genres
# Out:
# International Movies        2437
# Dramas                      2106
# Comedies                    1471
# Documentaries                786
# Action & Adventure           721
# Independent Movies           673
# Children & Family Movies     532
# Romantic Movies              531
# Thrillers                    491
# Stand-Up Comedy              329
# Music & Musicals             321
# Horror Movies                312
# Sci-Fi & Fantasy             218
# Sports Movies                196
# Classic Movies               103
# LGBTQ Movies                  90
# Cult Movies                   59
# Anime Features                57
# Faith & Spirituality          57
# Movies                        56
# Name: listed_in, dtype: int64

# %%
genres_index = genres["index"].str.strip()
genres["index"] = genres_index
genres.set_index("index",inplace=True)
genres
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-4abcf281655a> in <module>
# ...

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %% [markdown]
# # My Own Questions:
# how many movie shows don't have a director?
#
# what are the most common top 5 movie countries?
#
# who is the most common director for movies? (make sure that none are overlaped)
#
# what is the oldest movie?
#
# what is the oldest tv show?

# %% [markdown]
# # No director tv shows

# %%
tv["director"].isna().sum()
# Out:
# 2226

# %% [markdown]
# # top 5 movie countries

# %%
movies
# Out:
#      show_id   type                                    title  \
# 1         s2  Movie                                     7:19
# 2         s3  Movie                                    23:59
# 3         s4  Movie                                        9
# 4         s5  Movie                                       21
# 6         s7  Movie                                      122
# ...      ...    ...                                      ...
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7783   s7784  Movie                                   Zubaan
# 7784   s7785  Movie                        Zulu Man in Japan
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# ...

# %%
top5_movies = movies["country"].str.split(",").explode().str.strip().value_counts().head(10).plot.bar()
top5_movies
# Out:
# <AxesSubplot:>

# %% [markdown]
# # most common director for movies

# %%
top5_directors = movies["director"].str.split(",").explode().str.strip().value_counts().head(10).plot.bar()

# %% [markdown]
# # oldest movie

# %%
oldest_movie = movies["release_year"].min()
oldest_movie
# Out:
# 1942

# %%
oldest_bool = movies["release_year"] == 1942
oldest = movies[oldest_bool]
oldest
# Out:
#      show_id   type                 title     director  \
# 4960   s4961  Movie        Prelude to War  Frank Capra
# 6117   s6118  Movie  The Battle of Midway    John Ford
#
#                            cast        country      date_added  release_year  \
# 4960                        NaN  United States  March 31, 2017          1942
# 6117  Henry Fonda, Jane Darwell  United States  March 31, 2017          1942
#
#      rating duration                      listed_in  \
# 4960  TV-14   52 min  Classic Movies, Documentaries
# 6117  TV-14   18 min  Classic Movies, Documentaries
#
#                                             description  duration_int
# 4960  Frank Capra's documentary chronicles the rise ...            52
# 6117  Director John Ford captures combat footage of ...            18

# %% [markdown]
# # oldest tv show

# %%
oldest_tv = tv["release_year"].min()
oldest_tv
# Out:
# 1925

# %%
oldesttv_bool = tv["release_year"] == 1925
oldesttv = tv[oldesttv_bool]
oldesttv
# Out:
#      show_id     type                              title director cast  \
# 4867   s4868  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN
#
#      country         date_added  release_year rating  duration listed_in  \
# 4867     NaN  December 30, 2018          1925  TV-14  1 Season  TV Shows
#
#                                             description tv_striped  \
# 4867  This collection restores films from women who ...         1
#
#      tv_striped_s
# 4867           1
